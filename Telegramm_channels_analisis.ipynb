# %% [markdown]
# <a href="https://colab.research.google.com/github/K7chyp/tg_py_topic_modelling/blob/main/Telegramm_channels_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#import some csv, which I was parsed. 
data_ = pd.read_csv('/telegram_datasciencecourse.csv')
mipt = pd.read_csv('/telegram_dls_fall2020_advanced.csv')
python_academy = pd.read_csv('/telegram_python_academy_chat.csv')
tkhirianov = pd.read_csv('/telegram_tkhirianov_python_2019.csv')
coursera = pd.read_csv('/telegram_python_coursera.csv')
# Out:
# Mounted at content/

# %%
df = pd.concat([data_, mipt, python_academy, tkhirianov, coursera], ignore_index=True)

# %%
# do some prerpoce, from my github module 
from Preprocessing import Preprocessing

prep = Preprocessing()
df = prep.preproce_it()

# %%
# actually, steammer works not good with russian words, 
# but it do their work 

df.head()
# Out:
#   sender_username  ...                                          clear_msg
# 0        ololoput  ...  [, ннно, б, прост, 3, месяц, посчита, ошибк, м...
# 1    Sergey_Ilyin  ...  [train_df, , df3nm, , prophetyearly_seasonalit...
# 2    Sergey_Ilyin  ...  [ок, комут, бред, станет, трудн, чита, , дайт,...
# 3        ololoput  ...                        [чат, мож, добав, , полезн]
# 4    Sergey_Ilyin  ...                   [мог, личн, написа, чат, засоря]
#
# [5 rows x 3 columns]

# %%
# get some topics

model = Model()
model.plot_it()
